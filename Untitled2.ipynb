# %% [markdown]
# <h1 align='center'>Análisis Mesa 91</h1>
#
# Breve análisis del por qué el cálculo no estaba malo, sino los supuestos. Partamos de la base que sabíamos que el último folio era el número 56.000, y teníamos 350 folios:

# %%
folio_end = 56000
folio_start01 = folio_end - 350
print(folio_start01)
# Out:
# 55650

# %% [markdown]
# ---
#
# De este cálculo se extrae (erróneamente) que los folios entregados iban del número 55.650 al 56.000, pero veamos qué sucede cuándo efectivamente creamos una lista con este rango de números, extremos inclusive:

# %%
folio_list01 = [folio for folio in range(folio_start01, folio_end + 1)]
print(folio_list01)
# Out:
# [55650, 55651, 55652, 55653, 55654, 55655, 55656, 55657, 55658, 55659, 55660, 55661, 55662, 55663, 55664, 55665, 55666, 55667, 55668, 55669, 55670, 55671, 55672, 55673, 55674, 55675, 55676, 55677, 55678, 55679, 55680, 55681, 55682, 55683, 55684, 55685, 55686, 55687, 55688, 55689, 55690, 55691, 55692, 55693, 55694, 55695, 55696, 55697, 55698, 55699, 55700, 55701, 55702, 55703, 55704, 55705, 55706, 55707, 55708, 55709, 55710, 55711, 55712, 55713, 55714, 55715, 55716, 55717, 55718, 55719, 55720, 55721, 55722, 55723, 55724, 55725, 55726, 55727, 55728, 55729, 55730, 55731, 55732, 55733, 55734, 55735, 55736, 55737, 55738, 55739, 55740, 55741, 55742, 55743, 55744, 55745, 55746, 55747, 55748, 55749, 55750, 55751, 55752, 55753, 55754, 55755, 55756, 55757, 55758, 55759, 55760, 55761, 55762, 55763, 55764, 55765, 55766, 55767, 55768, 55769, 55770, 55771, 55772, 55773, 55774, 55775, 55776, 55777, 55778, 55779, 55780, 55781, 55782, 55783, 55784, 55785, 55786, 55787, 55788, 55789, 55790, 55791, 557
# ...

# %% [markdown]
# ---
#
# Nótese que se suma un 1 al final de la línea que genera nuestra lista, pues el comando *range* en Python incluye en el cálculo el primer valor, pero exluye el último. De esta forma, para que el último valor (en este caso el número 56.000) sea incluído, es necesario hacer el ajuste precedente. Pero hay un consideración importante que hacer. Observemos cuál es el largo de la lista generada:

# %%
print(len(folio_list))
# Out:
# 351

# %% [markdown]
# ---
#
# ¡Ahá! Lo tenemos... Violamos sin darnos cuenta la regla de que debían ser en total 350 los votos. El error está entonces en nuestro primer supuesto y, específicamente, en un dato que no pudimos observar y tuvimos que asumir: el folio inicial. Es así, que siendo el último folio observado el número 57.794, tenemos la siguiente situación:

# %%
folio_start02 = 55651
folio_list02 = [folio for folio in range(folio_start02, folio_end + 1)]
print(folio_list02)
# Out:
# [55651, 55652, 55653, 55654, 55655, 55656, 55657, 55658, 55659, 55660, 55661, 55662, 55663, 55664, 55665, 55666, 55667, 55668, 55669, 55670, 55671, 55672, 55673, 55674, 55675, 55676, 55677, 55678, 55679, 55680, 55681, 55682, 55683, 55684, 55685, 55686, 55687, 55688, 55689, 55690, 55691, 55692, 55693, 55694, 55695, 55696, 55697, 55698, 55699, 55700, 55701, 55702, 55703, 55704, 55705, 55706, 55707, 55708, 55709, 55710, 55711, 55712, 55713, 55714, 55715, 55716, 55717, 55718, 55719, 55720, 55721, 55722, 55723, 55724, 55725, 55726, 55727, 55728, 55729, 55730, 55731, 55732, 55733, 55734, 55735, 55736, 55737, 55738, 55739, 55740, 55741, 55742, 55743, 55744, 55745, 55746, 55747, 55748, 55749, 55750, 55751, 55752, 55753, 55754, 55755, 55756, 55757, 55758, 55759, 55760, 55761, 55762, 55763, 55764, 55765, 55766, 55767, 55768, 55769, 55770, 55771, 55772, 55773, 55774, 55775, 55776, 55777, 55778, 55779, 55780, 55781, 55782, 55783, 55784, 55785, 55786, 55787, 55788, 55789, 55790, 55791, 55792, 557
# ...

# %% [markdown]
# ---
#
# Ahora entonces, observemos el valor del largo de la lista para verificar que estemos bien, y corroboremos los votos sufragados para verificar que contamos bien las firmas:

# %%
print(f'El largo de la lista real es de {len(folio_list02)} y parte del folio {folio_start02}, terminando en el {folio_end}.')

folio_last = 55794
print(f'Los votos sufragados fueron {folio_last - folio_start02}.')
# Out:
# El largo de la lista real es de 350 y parte del folio 55651, terminando en el 56000.
# Los votos sufragados fueron 143.

# %% [markdown]
# ---
#
# Revisemos una última cosa: si extraemos los votos hasta el folio 55.794 (sin incluirlo), se debiera generar una lista de 143 elementos. A continuación vemos el despliegue de la lista:

# %%
folio_emitted = [folio for folio in folio_list02 if folio >= folio_last]
print(folio_emitted)
# Out:
# [55794, 55795, 55796, 55797, 55798, 55799, 55800, 55801, 55802, 55803, 55804, 55805, 55806, 55807, 55808, 55809, 55810, 55811, 55812, 55813, 55814, 55815, 55816, 55817, 55818, 55819, 55820, 55821, 55822, 55823, 55824, 55825, 55826, 55827, 55828, 55829, 55830, 55831, 55832, 55833, 55834, 55835, 55836, 55837, 55838, 55839, 55840, 55841, 55842, 55843, 55844, 55845, 55846, 55847, 55848, 55849, 55850, 55851, 55852, 55853, 55854, 55855, 55856, 55857, 55858, 55859, 55860, 55861, 55862, 55863, 55864, 55865, 55866, 55867, 55868, 55869, 55870, 55871, 55872, 55873, 55874, 55875, 55876, 55877, 55878, 55879, 55880, 55881, 55882, 55883, 55884, 55885, 55886, 55887, 55888, 55889, 55890, 55891, 55892, 55893, 55894, 55895, 55896, 55897, 55898, 55899, 55900, 55901, 55902, 55903, 55904, 55905, 55906, 55907, 55908, 55909, 55910, 55911, 55912, 55913, 55914, 55915, 55916, 55917, 55918, 55919, 55920, 55921, 55922, 55923, 55924, 55925, 55926, 55927, 55928, 55929, 55930, 55931, 55932, 55933, 55934, 55935, 559
# ...

# %% [markdown]
# ---
#
# Redoble de tambores, pues ahora si esta lista suma 143 elementos, ¡nos salvamos!

# %%
print(f'El largo de la lista de votos sufragados es: {len(folio_emitted)}')

if len(folio_emitted) == 143:
    print('\nNos salvamos!')
# Out:
# El largo de la lista de votos sufragados es: 207
